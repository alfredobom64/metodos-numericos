# %%
import math




def f(xi):
    return math.exp(xi)-1

def fd(xi):
    return math.exp(xi)

def g(xi):
    return (math.sin(2*xi))**3+xi**2

def gd(xi):
    return 2*((xi+3*(math.sin(2*xi))**2)*(math.cos(2*xi)))

def m(xi):
    return xi**4 + 3*xi**2 -(math.cos(xi))
def md(xi):
    return 4*xi**3+6*xi+(math.sin(xi))



def f2(h):
    xi=-5
    while(xi<=5):
            
        derivadaad=(f(xi+h)-f(xi))/h
        derivadaat=(f(xi)-f(xi-h))/h
        derivadace=(f(xi+h)-f(xi-h))/(2*h)
        
        errorvad1=math.fabs(fd(xi)-derivadaad)
        errorvat1=math.fabs(fd(xi)-derivadaat)
        errorvac1=math.fabs(fd(xi)-derivadace)
        
        errorrd1=math.fabs(fd(xi)-derivadaad)/fd(xi)
        errorrt1=math.fabs(fd(xi)-derivadaat)/fd(xi)
        errorrc1=math.fabs(fd(xi)-derivadaad)/fd(xi)
        
        errorpd1=(math.fabs(fd(xi)-derivadaad)/fd(xi))*0.1
        errorpt1=(math.fabs(fd(xi)-derivadaad)/fd(xi))*0.1
        errorpc1=(math.fabs(fd(xi)-derivadaad)/fd(xi))*0.1
        
        
        derivadag1=(g(xi+h)-g(xi))/h
        derivadag2=(g(xi)-g(xi-h))/h
        derivadag3=(g(xi+h)-g(xi-h))/(2*h)
        
        errorvad2=math.fabs(gd(xi)-derivadag1)
        errorvat2=math.fabs(gd(xi)-derivadag2)
        errorvac2=math.fabs(gd(xi)-derivadag3)
        if(xi !=0):

            errorrd2=math.fabs(gd(xi)-derivadag1)/gd(xi)
            errorrt2=math.fabs(gd(xi)-derivadag2)/gd(xi)
            errorrc2=math.fabs(gd(xi)-derivadag3)/gd(xi)

            errorpd2=(math.fabs(gd(xi)-derivadag1)/gd(xi))*0.1
            errorpt2=(math.fabs(gd(xi)-derivadag2)/gd(xi))*0.1
            errorpc2=(math.fabs(gd(xi)-derivadag3)/gd(xi))*0.1
 
        derivadam1=(m(xi+h)-m(xi))/h
        derivadam2=(m(xi)-m(xi-h))/h
        derivadam3=(m(xi+h)-m(xi-h))/(2*h)
        
        errorvad3=math.fabs(gd(xi)-derivadam1)
        errorvat3=math.fabs(gd(xi)-derivadam2)
        errorvac3=math.fabs(gd(xi)-derivadam3)
        if(xi !=0):
            errorrd3=math.fabs(md(xi)-derivadam1)/md(xi)
            errorrt3=math.fabs(md(xi)-derivadam2)/md(xi)
            errorrc3=math.fabs(md(xi)-derivadam3)/md(xi)

            errorpd3=(math.fabs(md(xi)-derivadam1)/md(xi))*0.1
            errorpt3=(math.fabs(md(xi)-derivadam2)/md(xi))*0.1
            errorpc3=(math.fabs(md(xi)-derivadam3)/md(xi))*0.1
      

        print "valor de xi:", xi
        print 
        print "el valor de la derivada adelante de la 1 funcion ", derivadaad
        print "el valor de la derivada atras de la 1 funcion ", derivadaat
        print "el valor de la derivada central de la 1 funcion", derivadace
        print
        print "ERROR ABSOLUTO"
        print "error absoluto de la 1 funcion hacia adelante",errorvad1
        print "error absoluto de la 1 funcion hacia atras",errorvat1
        print "error absoluto de la 1 funcion en el centro",errorvac1
        print
       
        print "ERROR RELATIVO"
        print "error relativo de la 1 funcion hacia adelante",errorrd1
        print "error relativo de la 1 funcion hacia atras",errorrt1
        print "error relativo de la 1 funcion en el centro",errorrc1
        print
 
        print "ERROR RELATIVO PORCENTUAL"
        print "error relativo de la 1 funcion hacia adelante",errorpd1
        print "error relativo de la 1 funcion hacia atras",errorpt1
        print "error relativo de la 1 funcion en el centro",errorpc1
        
        
        print"---------------------------------------------------------------"
        print "el valor de la derivada adelante de la 2 funcion ", derivadag1
        print "el valor de la derivada atras de la 2 funcion ", derivadag2
        print "el valor de la derivada central de la 2 funcion", derivadag3
        print
        print "ERROR ABSOLUTO"
        print
        print "error absoluto de la 2 funcion hacia adelante",errorvad2
        print "error absoluto de la 2 funcion hacia atras",errorvat2
        print "error absoluto de la 2 funcion en el centro",errorvac2
        print
        if(xi !=0):
            print "ERROR RELATIVO"
            print
            print "error relativo de la 2 funcion hacia adelante",errorrd2
            print "error relativo de la 2 funcion hacia atras",errorrt2
            print "error relativo de la 2 funcion en el centro",errorrc2
            print
            print "ERROR RELATIVO PORCENTUAL"
            print "error relativo de la 2 funcion hacia adelante",errorpd2
            print "error relativo de la 2 funcion hacia atras",errorpt2
            print "error relativo de la 2 funcion en el centro",errorpc2
        
        print"--------------------------------------------------------------"
        print "el valor de la derivada adelante de la 3 funcion ", derivadam1
        print "el valor de la derivada atras de la 3 funcion ", derivadam2
        print "el valor de la derivada central de la 3 funcion", derivadam3
        print
        print "ERROR ABSOLUTO"
        print
        print "error absoluto de la 3funcion hacia adelante",errorvad3
        print "error absoluto de la 3funcion hacia atras",errorvat3
        print "error absoluto de la 3funcion en el centro",errorvac3
        print
        if(xi !=0):
            print "ERROR RELATIVO"
            print
            print "error relativo de la 3 funcion hacia adelante",errorrd3
            print "error relativo de la 3 funcion hacia atras",errorrt3
            print "error relativo de la 3 funcion en el centro",errorrc3
            print
            print "ERROR RELATIVO PORCENTUAL"
            print "error relativo de la 3 funcion hacia adelante",errorpd3
            print "error relativo de la 3 funcion hacia adelante",errorpt3
            print "error relativo de la 3 funcion hacia adelante",errorpc3
            print
        xi=xi+h
            
h= input("ingrese h")
f2(h)
# Out:
# ingrese h2
# valor de xi: -5
#
# el valor de la derivada adelante de la 1 funcion  0.0215245606844
# el valor de la derivada atras de la 1 funcion  0.00291303251677
# el valor de la derivada central de la 1 funcion 0.0122187966006
#
# ERROR ABSOLUTO
# error absoluto de la 1 funcion hacia adelante 0.0147866136853
# error absoluto de la 1 funcion hacia atras 0.00382491448232
# error absoluto de la 1 funcion en el centro 0.00548084960149
#
# ERROR RELATIVO
# error relativo de la 1 funcion hacia adelante 2.19452804947
# error relativo de la 1 funcion hacia atras 0.567667641618
# error relativo de la 1 funcion en el centro 2.19452804947
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 1 funcion hacia adelante 0.219452804947
# error relativo de la 1 funcion hacia atras 0.219452804947
# error relativo de la 1 funcion en el centro 0.219452804947
# ---------------------------------------------------------------
# el valor de la derivada adelante de la 2 funcion  -8.06959655759
# el valor de la derivada atras de la 2 funcion  -11.4334530846
# el valor de la derivada central de la 2 funcion -9.75152482107
#
# ERROR ABSOLUTO
#
# error absoluto de la 2 funcion hacia adelante 14.9703273799
# error absoluto de la 2 funcion hacia atras 18.3341839069
# error absoluto de la 2 funcion en el centro 16.6522556434
#
# ERROR RELATIVO
#
# error relativo de la 2 funcion hacia adelante 2.16938289079
# error relativo de la 2 funcion hacia atras 2.65684669913
# error relativo de la 2 funcion en el centro 2.41311479496
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 2 funcion hacia adelante 0.216938289079
# error relativo de la 2 funcion hacia atras 0.265684669913
# error relativo de la 2 funcion en el centro 0.241311479496
# --------------------------------------------------------------
# el valor de la derivada adelante de la 3 funcion  -295.363172659
# el valor de la derivada atras de la 3 funcion  -923.764879966
# el valor de la derivada central de la 3 funcion -609.564026312
#
# ERROR ABSOLUTO
#
# error absoluto de la 3funcion hacia adelante 302.263903481
# error absoluto de la 3funcion hacia atras 930.665610788
# error absoluto de la 3funcion en el centro 616.464757135
#
# ERROR RELATIVO
#
# error relativo de la 3 funcion hacia adelante -0.441700869344
# error relativo de la 3 funcion hacia atras -0.746111828272
# error relativo de la 3 funcion en el centro -0.152205479464
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 3 funcion hacia adelante -0.0441700869344
# error relativo de la 3 funcion hacia adelante -0.0746111828272
# error relativo de la 3 funcion hacia adelante -0.0152205479464
#
# valor de xi: -3
#
# el valor de la derivada adelante de la 1 funcion  0.159046186402
# el valor de la derivada atras de la 1 funcion  0.0215245606844
# el valor de la derivada central de la 1 funcion 0.0902853735431
#
# ERROR ABSOLUTO
# error absoluto de la 1 funcion hacia adelante 0.109259118034
# error absoluto de la 1 funcion hacia atras 0.0282625076835
# error absoluto de la 1 funcion en el centro 0.0404983051752
#
# ERROR RELATIVO
# error relativo de la 1 funcion hacia adelante 2.19452804947
# error relativo de la 1 funcion hacia atras 0.567667641618
# error relativo de la 1 funcion en el centro 2.19452804947
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 1 funcion hacia adelante 0.219452804947
# error relativo de la 1 funcion hacia atras 0.219452804947
# error relativo de la 1 funcion en el centro 0.219452804947
# ---------------------------------------------------------------
# el valor de la derivada adelante de la 2 funcion  -4.38682087831
# el valor de la derivada atras de la 2 funcion  -8.06959655759
# el valor de la derivada central de la 2 funcion -6.22820871795
#
# ERROR ABSOLUTO
#
# error absoluto de la 2 funcion hacia adelante 0.92442047398
# error absoluto de la 2 funcion hacia atras 2.7583552053
# error absoluto de la 2 funcion en el centro 0.91696736566
#
# ERROR RELATIVO
#
# error relativo de la 2 funcion hacia adelante -0.17404979602
# error relativo de la 2 funcion hacia atras -0.519342847056
# error relativo de la 2 funcion en el centro -0.172646525518
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 2 funcion hacia adelante -0.017404979602
# error relativo de la 2 funcion hacia atras -0.0519342847056
# error relativo de la 2 funcion en el centro -0.0172646525518
# --------------------------------------------------------------
# el valor de la derivada adelante de la 3 funcion  -52.7651474012
# el valor de la derivada atras de la 3 funcion  -295.363172659
# el valor de la derivada central de la 3 funcion -174.06416003
#
# ERROR ABSOLUTO
#
# error absoluto de la 3funcion hacia adelante 47.4539060489
# error absoluto de la 3funcion hacia atras 290.051931307
# error absoluto de la 3funcion en el centro 168.752918678
#
# ERROR RELATIVO
#
# error relativo de la 3 funcion hacia adelante -0.58169748772
# error relativo de la 3 funcion hacia atras -1.3415296506
# error relativo de la 3 funcion en el centro -0.379916081441
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 3 funcion hacia adelante -0.058169748772
# error relativo de la 3 funcion hacia adelante -0.13415296506
# error relativo de la 3 funcion hacia adelante -0.0379916081441
#
# valor de xi: -1
#
# el valor de la derivada adelante de la 1 funcion  1.17520119364
# el valor de la derivada atras de la 1 funcion  0.159046186402
# el valor de la derivada central de la 1 funcion 0.667123690023
#
# ERROR ABSOLUTO
# error absoluto de la 1 funcion hacia adelante 0.807321752472
# error absoluto de la 1 funcion hacia atras 0.20883325477
# error absoluto de la 1 funcion en el centro 0.299244248851
#
# ERROR RELATIVO
# error relativo de la 1 funcion hacia adelante 2.19452804947
# error relativo de la 1 funcion hacia atras 0.567667641618
# error relativo de la 1 funcion en el centro 2.19452804947
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 1 funcion hacia adelante 0.219452804947
# error relativo de la 1 funcion hacia atras 0.219452804947
# error relativo de la 1 funcion en el centro 0.219452804947
# ---------------------------------------------------------------
# el valor de la derivada adelante de la 2 funcion  0.751826944669
# el valor de la derivada atras de la 2 funcion  -4.38682087831
# el valor de la derivada central de la 2 funcion -1.81749696682
#
# ERROR ABSOLUTO
#
# error absoluto de la 2 funcion hacia adelante 1.98400895637
# error absoluto de la 2 funcion hacia atras 3.15463886661
# error absoluto de la 2 funcion en el centro 0.58531495512
#
# ERROR RELATIVO
#
# error relativo de la 2 funcion hacia adelante -1.61015900048
# error relativo de la 2 funcion hacia atras -2.56020525917
# error relativo de la 2 funcion en el centro -0.475023129344
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 2 funcion hacia adelante -0.161015900048
# error relativo de la 2 funcion hacia atras -0.256020525917
# error relativo de la 2 funcion en el centro -0.0475023129344
# --------------------------------------------------------------
# el valor de la derivada adelante de la 3 funcion  0.0
# el valor de la derivada atras de la 3 funcion  -52.7651474012
# el valor de la derivada central de la 3 funcion -26.3825737006
#
# ERROR ABSOLUTO
#
# error absoluto de la 3funcion hacia adelante 1.2321820117
# error absoluto de la 3funcion hacia atras 51.5329653895
# error absoluto de la 3funcion en el centro 25.1503916889
#
# ERROR RELATIVO
#
# error relativo de la 3 funcion hacia adelante -1.0
# error relativo de la 3 funcion hacia atras -3.86697307729
# error relativo de la 3 funcion en el centro -1.43348653864
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 3 funcion hacia adelante -0.1
# error relativo de la 3 funcion hacia adelante -0.386697307729
# error relativo de la 3 funcion hacia adelante -0.143348653864
#
# valor de xi: 1
#
# el valor de la derivada adelante de la 1 funcion  8.68362754736
# el valor de la derivada atras de la 1 funcion  1.17520119364
# el valor de la derivada central de la 1 funcion 4.9294143705
#
# ERROR ABSOLUTO
# error absoluto de la 1 funcion hacia adelante 5.96534571891
# error absoluto de la 1 funcion hacia atras 1.54308063482
# error absoluto de la 1 funcion en el centro 2.21113254205
#
# ERROR RELATIVO
# error relativo de la 1 funcion hacia adelante 2.19452804947
# error relativo de la 1 funcion hacia atras 0.567667641618
# error relativo de la 1 funcion en el centro 2.19452804947
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 1 funcion hacia adelante 0.219452804947
# error relativo de la 1 funcion hacia atras 0.219452804947
# error relativo de la 1 funcion en el centro 0.219452804947
# ---------------------------------------------------------------
# el valor de la derivada adelante de la 2 funcion  3.61317912169
# el valor de la derivada atras de la 2 funcion  0.751826944669
# el valor de la derivada central de la 2 funcion 2.18250303318
#
# ERROR ABSOLUTO
#
# error absoluto de la 2 funcion hacia adelante 6.50994847958
# error absoluto de la 2 funcion hacia atras 3.64859630256
# error absoluto de la 2 funcion en el centro 5.07927239107
#
# ERROR RELATIVO
#
# error relativo de la 2 funcion hacia adelante -2.24731336026
# error relativo de la 2 funcion hacia atras -1.25953980168
# error relativo de la 2 funcion en el centro -1.75342658097
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 2 funcion hacia adelante -0.224731336026
# error relativo de la 2 funcion hacia atras -0.125953980168
# error relativo de la 2 funcion en el centro -0.175342658097
# --------------------------------------------------------------
# el valor de la derivada adelante de la 3 funcion  52.7651474012
# el valor de la derivada atras de la 3 funcion  0.0
# el valor de la derivada central de la 3 funcion 26.3825737006
#
# ERROR ABSOLUTO
#
# error absoluto de la 3funcion hacia adelante 55.6619167591
# error absoluto de la 3funcion hacia atras 2.89676935789
# error absoluto de la 3funcion en el centro 29.2793430585
#
# ERROR RELATIVO
#
# error relativo de la 3 funcion hacia adelante 3.86697307729
# error relativo de la 3 funcion hacia atras 1.0
# error relativo de la 3 funcion en el centro 1.43348653864
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 3 funcion hacia adelante 0.386697307729
# error relativo de la 3 funcion hacia adelante 0.1
# error relativo de la 3 funcion hacia adelante 0.143348653864
#
# valor de xi: 3
#
# el valor de la derivada adelante de la 1 funcion  64.1638110897
# el valor de la derivada atras de la 1 funcion  8.68362754736
# el valor de la derivada central de la 1 funcion 36.4237193185
#
# ERROR ABSOLUTO
# error absoluto de la 1 funcion hacia adelante 44.0782741665
# error absoluto de la 1 funcion hacia atras 11.4019093758
# error absoluto de la 1 funcion en el centro 16.3381823953
#
# ERROR RELATIVO
# error relativo de la 1 funcion hacia adelante 2.19452804947
# error relativo de la 1 funcion hacia atras 0.567667641618
# error relativo de la 1 funcion en el centro 2.19452804947
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 1 funcion hacia adelante 0.219452804947
# error relativo de la 1 funcion hacia atras 0.219452804947
# error relativo de la 1 funcion en el centro 0.219452804947
# ---------------------------------------------------------------
# el valor de la derivada adelante de la 2 funcion  7.93040344241
# el valor de la derivada atras de la 2 funcion  3.61317912169
# el valor de la derivada central de la 2 funcion 5.77179128205
#
# ERROR ABSOLUTO
#
# error absoluto de la 2 funcion hacia adelante 1.71960135489
# error absoluto de la 2 funcion hacia atras 2.59762296582
# error absoluto de la 2 funcion en el centro 0.439010805465
#
# ERROR RELATIVO
#
# error relativo de la 2 funcion hacia adelante 0.276872669691
# error relativo de la 2 funcion hacia atras 0.418242753387
# error relativo de la 2 funcion en el centro 0.0706850418479
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 2 funcion hacia adelante 0.0276872669691
# error relativo de la 2 funcion hacia atras 0.0418242753387
# error relativo de la 2 funcion en el centro 0.00706850418479
# --------------------------------------------------------------
# el valor de la derivada adelante de la 3 funcion  295.363172659
# el valor de la derivada atras de la 3 funcion  52.7651474012
# el valor de la derivada central de la 3 funcion 174.06416003
#
# ERROR ABSOLUTO
#
# error absoluto de la 3funcion hacia adelante 289.152370571
# error absoluto de la 3funcion hacia atras 46.5543453137
# error absoluto de la 3funcion en el centro 167.853357943
#
# ERROR RELATIVO
#
# error relativo de la 3 funcion hacia adelante 1.3415296506
# error relativo de la 3 funcion hacia atras 0.58169748772
# error relativo de la 3 funcion en el centro 0.379916081441
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 3 funcion hacia adelante 0.13415296506
# error relativo de la 3 funcion hacia adelante 0.058169748772
# error relativo de la 3 funcion hacia adelante 0.0379916081441
#
# valor de xi: 5
#
# el valor de la derivada adelante de la 1 funcion  474.109999663
# el valor de la derivada atras de la 1 funcion  64.1638110897
# el valor de la derivada central de la 1 funcion 269.136905376
#
# ERROR ABSOLUTO
# error absoluto de la 1 funcion hacia adelante 325.69684056
# error absoluto de la 1 funcion hacia atras 84.2493480129
# error absoluto de la 1 funcion en el centro 120.723746274
#
# ERROR RELATIVO
# error relativo de la 1 funcion hacia adelante 2.19452804947
# error relativo de la 1 funcion hacia atras 0.567667641618
# error relativo de la 1 funcion en el centro 2.19452804947
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 1 funcion hacia adelante 0.219452804947
# error relativo de la 1 funcion hacia atras 0.219452804947
# error relativo de la 1 funcion en el centro 0.219452804947
# ---------------------------------------------------------------
# el valor de la derivada adelante de la 2 funcion  12.5665469154
# el valor de la derivada atras de la 2 funcion  7.93040344241
# el valor de la derivada central de la 2 funcion 10.2484751789
#
# ERROR ABSOLUTO
#
# error absoluto de la 2 funcion hacia adelante 22.4472466747
# error absoluto de la 2 funcion hacia atras 17.8111032016
# error absoluto de la 2 funcion en el centro 20.1291749381
#
# ERROR RELATIVO
#
# error relativo de la 2 funcion hacia adelante -2.27182762574
# error relativo de la 2 funcion hacia atras -1.80261556728
# error relativo de la 2 funcion en el centro -2.03722159651
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 2 funcion hacia adelante -0.227182762574
# error relativo de la 2 funcion hacia atras -0.180261556728
# error relativo de la 2 funcion en el centro -0.203722159651
# --------------------------------------------------------------
# el valor de la derivada adelante de la 3 funcion  923.764879966
# el valor de la derivada atras de la 3 funcion  295.363172659
# el valor de la derivada central de la 3 funcion 609.564026312
#
# ERROR ABSOLUTO
#
# error absoluto de la 3funcion hacia adelante 933.645579725
# error absoluto de la 3funcion hacia atras 305.243872418
# error absoluto de la 3funcion en el centro 619.444726071
#
# ERROR RELATIVO
#
# error relativo de la 3 funcion hacia adelante 0.746111828272
# error relativo de la 3 funcion hacia atras 0.441700869344
# error relativo de la 3 funcion en el centro 0.152205479464
#
# ERROR RELATIVO PORCENTUAL
# error relativo de la 3 funcion hacia adelante 0.0746111828272
# error relativo de la 3 funcion hacia adelante 0.0441700869344
# error relativo de la 3 funcion hacia adelante 0.0152205479464
