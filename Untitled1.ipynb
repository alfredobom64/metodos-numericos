# %%
import math
n=5
err=100
es=(0.5*(10**(2-n)))
m=68.1
c=12.5
g=9.8
va=0
t=0
aux=0
while err > es:
    f=1-math.exp(-(c/m)*(t))
    va=aux
    aux = va + (g-((c*va)/m))
    v=((m*g)/c)*f
    err=(aux-v)
    print "Tiempo :",t # imprime el tiempo en el que ser calcula la velocidad
    t +=1
    print "valor :",v # imprimir valor de funcion
    print "valor calculado :",aux # imprimir valor de funcion calculado
    print "error :",err # imprimir porcentaje de error
    print "" # salto de linea
# Out:
# Tiempo : 0
# valor : 0.0
# valor calculado : 9.8
# error : 9.8
#
# Tiempo : 1
# valor : 8.9531822079
# valor calculado : 17.801174743
# error : 8.84799253512
#
# Tiempo : 2
# valor : 16.4049808029
# valor calculado : 24.3337050765
# error : 7.92872427367
#
# Tiempo : 3
# valor : 22.6071669095
# valor calculado : 29.6671659656
# error : 7.05999905607
#
# Tiempo : 4
# valor : 27.7692914639
# valor calculado : 34.0216509205
# error : 6.25235945663
#
# Tiempo : 5
# valor : 32.0657652324
# valor calculado : 37.576854496
# error : 5.51108926361
#
# Tiempo : 6
# valor : 35.6417515631
# valor calculado : 40.4794876649
# error : 4.83773610176
#
# Tiempo : 7
# valor : 38.6180709651
# valor calculado : 42.849332073
# error : 4.23126110785
#
# Tiempo : 8
# valor : 41.0952832258
# valor calculado : 44.784183014
# error : 3.68889978822
#
# Tiempo : 9
# valor : 43.1570849869
# valor calculado : 46.363885104
# error : 3.20680011704
#
# Tiempo : 10
# valor : 44.8731375713
# valor calculado : 47.6536271921
# error : 2.78048962074
#
# Tiempo : 11
# valor : 46.3014206042
# valor calculado : 48.7066324799
# error : 2.4052118757
#
# Tiempo : 12
# valor : 47.4901909486
# valor calculado : 49.5663548588
# error : 2.07616391012
#
# Tiempo : 13
# valor : 48.4796131425
# valor calculado : 50.268272102
# error : 1.78865895946
#
# Tiempo : 14
# valor : 49.3031164225
# valor calculado : 50.84134991
# error : 1.53823348749
#
# Tiempo : 15
# valor : 49.988524185
# valor calculado : 51.3092372246
# error : 1.32071303957
#
# Tiempo : 16
# valor : 50.5589940452
# valor calculado : 51.6912421393
# error : 1.13224809417
#
# Tiempo : 17
# valor : 51.0338002541
# valor calculado : 52.0031286776
# error : 0.969328423521
#
# Tiempo : 18
# valor : 51.4289849112
# valor calculado : 52.2577673198
# error : 0.828782408567
#
# Tiempo : 19
# valor : 51.7578999723
# valor calculado : 52.465666123
# error : 0.707766150792
#
# Tiempo : 20
# valor : 52.0316583671
# valor calculado : 52.635404353
# error : 0.603745985956
#
# Tiempo : 21
# valor : 52.2595094679
# valor calculado : 52.7739865202
# error : 0.514477052351
#
# Tiempo : 22
# valor : 52.4491515944
# valor calculado : 52.8871314321
# error : 0.437979837692
#
# Tiempo : 23
# valor : 52.606992114
# valor calculado : 52.9795081883
# error : 0.372516074305
#
# Tiempo : 24
# valor : 52.7383639252
# valor calculado : 53.0549288586
# error : 0.316564933428
#
# Tiempo : 25
# valor : 52.847705638
# valor calculado : 53.1165057935
# error : 0.268800155522
#
# Tiempo : 26
# valor : 52.9387115399
# valor calculado : 53.1667800605
# error : 0.228068520571
#
# Tiempo : 27
# valor : 53.0144564132
# valor calculado : 53.2078263049
# error : 0.193369891658
#
# Tiempo : 28
# valor : 53.0774994216
# valor calculado : 53.2413383635
# error : 0.163838941896
#
# Tiempo : 29
# valor : 53.1299705754
# valor calculado : 53.2686991631
# error : 0.13872858772
#
# Tiempo : 30
# valor : 53.1736426979
# valor calculado : 53.2910377896
# error : 0.117395091636
#
# Tiempo : 31
# valor : 53.2099913228
# valor calculado : 53.3092760808
# error : 0.0992847579793
#
# Tiempo : 32
# valor : 53.2402445473
# valor calculado : 53.324166668
# error : 0.0839221206797
#
# Tiempo : 33
# valor : 53.2654245259
# valor calculado : 53.3363240344
# error : 0.070899508492
#
# Tiempo : 34
# valor : 53.286382005
# valor calculado : 53.3462498724
# error : 0.059867867445
#
# Tiempo : 35
# valor : 53.3038250671
# valor calculado : 53.3543537872
# error : 0.0505287201064
#
# Tiempo : 36
# valor : 53.3183430544
# valor calculado : 53.3609701992
# error : 0.0426271448517
#
# Tiempo : 37
# valor : 53.3304264807
# valor calculado : 53.366372145
# error : 0.0359456643621
#
# Tiempo : 38
# valor : 53.3404836042
# valor calculado : 53.3707825442
# error : 0.0302989400911
#
# Tiempo : 39
# valor : 53.3488542211
# valor calculado : 53.3743833988
# error : 0.0255291777223
#
# Tiempo : 40
# valor : 53.3558211464
# valor calculado : 53.3773233036
# error : 0.0215021571919
#
# Tiempo : 41
# valor : 53.3616197689
# valor calculado : 53.3797235783
# error : 0.0181038093237
#
# Tiempo : 42
# valor : 53.3664460046
# valor calculado : 53.3816832739
# error : 0.0152372692781
#
# Tiempo : 43
# valor : 53.3704629156
# valor calculado : 53.3832832603
# error : 0.0128203447104
#
# Tiempo : 44
# valor : 53.3738062198
# valor calculado : 53.3845895635
# error : 0.0107833436694
#
# Tiempo : 45
# valor : 53.3765888762
# valor calculado : 53.38565609
# error : 0.00906721380955
#
# Tiempo : 46
# valor : 53.3789049013
# valor calculado : 53.3865268518
# error : 0.00762195042926
#
# Tiempo : 47
# valor : 53.3808325459
# valor calculado : 53.3872377821
# error : 0.00640523618598
#
# Tiempo : 48
# valor : 53.3824369384
# valor calculado : 53.3878182185
# error : 0.00538128011448
#
# Tiempo : 49
# valor : 53.383772286
# valor calculado : 53.3882921138
# error : 0.00451982781411
#
# Tiempo : 50
# valor : 53.3848837055
# valor calculado : 53.3886790239
# error : 0.00379531841839
#
# Tiempo : 51
# valor : 53.385808748
# valor calculado : 53.3889949153
# error : 0.00318616725713
#
# Tiempo : 52
# valor : 53.3865786676
# valor calculado : 53.3892528236
# error : 0.00267415601091
#
# Tiempo : 53
# valor : 53.3872194773
# valor calculado : 53.389463392
# error : 0.002243914682
#
# Tiempo : 54
# valor : 53.3877528278
# valor calculado : 53.3896353097
# error : 0.00188248190263
#
# Tiempo : 55
# valor : 53.3881967394
# valor calculado : 53.3897756714
# error : 0.00157893201047
#
# Tiempo : 56
# valor : 53.3885662102
# valor calculado : 53.3898902692
# error : 0.00132405897318
#
# Tiempo : 57
# valor : 53.3888737234
# valor calculado : 53.3899838321
# error : 0.0011101086733
#
# Tiempo : 58
# valor : 53.3891296689
# valor calculado : 53.3900602212
# error : 0.000930552295621
#
# Tiempo : 59
# valor : 53.3893426942
# valor calculado : 53.3901225888
# error : 0.000779894620734
#
# Tiempo : 60
# valor : 53.3895199967
# valor calculado : 53.3901735086
# error : 0.000653511939163
#
# Tiempo : 61
# valor : 53.3896675669
# valor calculado : 53.3902150819
# error : 0.000547515082886
#
# Tiempo : 62
# valor : 53.3897903906
# valor calculado : 53.3902490243
# error : 0.000458633740912
